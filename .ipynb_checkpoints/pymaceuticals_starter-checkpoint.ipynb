# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merge_df = pd.merge(study_results, mouse_metadata, on="Mouse ID", how="left")

# Display the data table for preview
merge_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
mouse_count = len(merge_df["Mouse ID"].unique())
mouse_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mouse_ID = merge_df.loc[merge_df.duplicated(subset=["Mouse ID", "Timepoint"]),"Mouse ID"].unique()
duplicate_mouse_ID
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
index_df = merge_df.set_index('Mouse ID')
index_df.loc["g989"]
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# Mouse ID
# g989              0           45.000000                 0     Propriva
# g989              0           45.000000                 0     Propriva
# g989              5           48.786801                 0     Propriva
# g989              5           47.570392                 0     Propriva
# g989             10           51.745156                 0     Propriva
# g989             10           49.880528                 0     Propriva
# g989             15           51.325852                 1     Propriva
# g989             15           53.442020                 0     Propriva
# g989             20           55.326122                 1     Propriva
# g989             20           54.657650                 1     Propriva
# g989             25           56.045564                 1     Propriva
# g989             30           59.082294                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = index_df.drop(['g989'])
clean_df
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# Mouse ID
# b128              0           45.000000                 0    Capomulin
# f932              0           45.000000                 0     Ketapril
# g107              0           45.000000                 0     Ketapril
# a457              0           45.000000                 0     Ketapril
# c819              0           45.000000                 0     Ketapril
# ...             ...                 ...               ...          ...
# r944             45           41.581521                 2    Capomulin
# u364             45           31.023923                 3    Capomulin
# p438             45           61.433892                 1     Ceftamin
# x773             45           58.634971                 4      Placebo
# b879             45           72.555239                 2     Stelasyn
#
#              Sex  Age_months  Weight (g)
# Mouse ID
# b128      Female           9          22
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_df2 = clean_df.reset_index()
mouse_count_clean = len(clean_df2["Mouse ID"].unique())
mouse_count_clean
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.

tumor = clean_df2.groupby(['Drug Regimen'])

tumor_mean = tumor['Tumor Volume (mm3)'].mean()
tumor_median = tumor['Tumor Volume (mm3)'].median()
tumor_variance = tumor['Tumor Volume (mm3)'].var()
tumor_std = tumor['Tumor Volume (mm3)'].std()
tumor_sem = tumor['Tumor Volume (mm3)'].sem()

tumor_df = pd.DataFrame({"Mean Tumor Volume": tumor_mean,
                         "Median Tumor Volume": tumor_median,
                         "Tumor Volume Variance": tumor_variance,
                         "Tumor Volume Std. Dev.": tumor_std,
                         "Tumor Volume Std. Err.": tumor_sem})
tumor_df
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
tumor2 = clean_df2.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean', 'median', 'var', 'std', 'sem'])
tumor2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
timepoint = clean_df2.groupby(['Drug Regimen'])['Timepoint'].count()

#use groupby to do a count for each drug regimen
timepoint.sort_values(ascending=False).plot.bar()
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
timepoint_desc = timepoint.sort_values(ascending=False)
plt.bar(timepoint_desc.index, timepoint_desc.values) #to create the bar chart
plt.xlabel("Drug Regimen") #To label the xaxis
plt.ylabel("# of Observed Mouse Timepoints") #To label the yaxis
plt.xticks(rotation='vertical') #To rotate the words on the x-axis so they are readable
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study
# Get the unique mice with their gender
sex = clean_df2['Sex'].value_counts()


# Make the pie chart
sex.plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender
mylabels = ["Female", "Male"]
colors = ["orange", "blue"]
plt.pie(sex, labels = mylabels, autopct="%1.1f%%", startangle = 180, colors=colors)
plt.ylabel("count")
plt.show()

# Make the pie chart

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin

drug_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
drugs = clean_df2[clean_df2["Drug Regimen"].isin(drug_list)]
drugs.head()

# Start by getting the last (greatest) timepoint for each mouse

last_timepoint = drugs.groupby("Mouse ID")["Timepoint"].max().reset_index()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor_volume_df = last_timepoint.merge(drugs, on=["Mouse ID", "Timepoint"], how="left")

#Filter for the four treatment regimens
final_tumor_volume_df = final_tumor_volume_df[final_tumor_volume_df["Drug Regimen"].isin(drug_list)]

# Display the final dataset
print(final_tumor_volume_df[["Mouse ID", "Drug Regimen", "Timepoint", "Tumor Volume (mm3)"]])
# Out:
#    Mouse ID Drug Regimen  Timepoint  Tumor Volume (mm3)
# 0      a203    Infubinol         45           67.973419
# 1      a251    Infubinol         45           65.525743
# 2      a275     Ceftamin         45           62.999356
# 3      a411     Ramicane         45           38.407618
# 4      a444     Ramicane         45           43.047543
# ..      ...          ...        ...                 ...
# 95     y769     Ceftamin         45           68.594745
# 96     y793    Capomulin         45           31.896238
# 97     y865     Ceftamin         45           64.729837
# 98     z578     Ramicane         45           30.638696
# 99     z581    Infubinol         45           62.754451
#
# [100 rows x 4 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_volumes = {}


# Calculate the IQR and quantitatively determine if there are any potential outliers.
for drug in treatments:
    # Get the tumor volume data for the current treatment
    drug_data = final_tumor_volume_df[final_tumor_volume_df["Drug Regimen"] == drug]["Tumor Volume (mm3)"]
    
    # Add to dictionary for later plotting
    tumor_volumes[drug] = drug_data

    # Calculate IQR
    quartiles = np.percentile(drug_data, [25, 75])
    lowerq, upperq = quartiles
    iqr = upperq - lowerq

    # Calculate lower and upper bounds
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)

    # Find potential outliers
    outliers = drug_data[(drug_data < lower_bound) | (drug_data > upper_bound)]
    
    print(f"\n{drug} - Potential Outliers:")
    print(outliers if not outliers.empty else "No outliers detected")

    # Locate the rows which contain mice on each drug and get the tumor volumes


    # add subset


    # Determine outliers using upper and lower bounds
# Out:
# Capomulin - Potential Outliers:
# No outliers detected
#
# Ramicane - Potential Outliers:
# No outliers detected
#
# Infubinol - Potential Outliers:
# 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
#
# Ceftamin - Potential Outliers:
# No outliers detected

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
